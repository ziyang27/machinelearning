# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Read data
data = pd.read_csv("housing.csv")

# %%
# Inspect data
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.shape
# Out:
# (20640, 10)

# %%
data.dropna(inplace = True)

# %%
data.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
# Split data
from sklearn.model_selection import train_test_split

X = data.drop(columns='median_house_value')
y = data['median_house_value']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16940    -122.33     37.55                51.0       2565.0           332.0
# 8380     -118.36     33.95                42.0       1116.0           303.0
# 15261    -117.26     33.02                 9.0       4632.0           759.0
# 10561    -117.71     33.62                22.0       2520.0           387.0
# 12931    -121.24     38.64                13.0       4491.0           689.0
# ...          ...       ...                 ...          ...             ...
# 7581     -118.23     33.89                16.0       5003.0          1180.0
# 106      -122.24     37.81                52.0       2026.0           482.0
# 4304     -118.30     34.09                25.0       2345.0           852.0
# 9301     -122.56     38.01                21.0       2144.0           400.0
# 20509    -121.53     38.60                25.0       5154.0          1105.0
#
# ...

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.drop('ocean_proximity', axis=1).corr(), annot=True, cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
# Transform the features
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
# One-hot encoding
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop('ocean_proximity', axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16940    -122.33     37.55                51.0     7.850104        5.808142
# 8380     -118.36     33.95                42.0     7.018402        5.717028
# 15261    -117.26     33.02                 9.0     8.440960        6.633318
# 10561    -117.71     33.62                22.0     7.832411        5.961005
# 12931    -121.24     38.64                13.0     8.410053        6.536692
# ...          ...       ...                 ...          ...             ...
# 7581     -118.23     33.89                16.0     8.517993        7.074117
# 106      -122.24     37.81                52.0     7.614312        6.180017
# 4304     -118.30     34.09                25.0     7.760467        6.748760
# 9301     -122.56     38.01                21.0     7.670895        5.993961
# 20509    -121.53     38.60                25.0     8.547722        7.008505
#
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='latitude', y='longitude', data=train_data, hue='median_house_value')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
# Feature engineer
train_data['bedroom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']
train_data['household_rooms'] = train_data['total_rooms'] / train_data['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
# Train model (Linear Regression)
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train, y_train = train_data.drop('median_house_value', axis=1), train_data['median_house_value']
X_train_s = scaler.fit_transform(X_train)

model = LinearRegression()

model.fit(X_train_s, y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(y_test)

# Transform the features
test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop('ocean_proximity', axis=1)

test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']

test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1999     -119.77     36.74                20.0     7.526179        6.253829
# 1625     -122.16     37.83                16.0     8.433159        6.559615
# 5759     -118.29     34.17                17.0     8.256607        6.972606
# 9767     -121.31     36.42                21.0     7.916078        6.423247
# 7103     -118.00     33.89                34.0     7.566828        5.755742
# ...          ...       ...                 ...          ...             ...
# 14201    -117.02     32.71                30.0     8.067149        6.385194
# 17371    -120.43     34.97                28.0     7.268223        5.602119
# 16282    -121.29     37.93                37.0     7.819636        6.361302
# 1747     -122.36     37.96                30.0     6.857514        5.762051
# 10099    -117.95     33.93                37.0     7.876259        6.447306
#
# ...

# %%
X_test, y_test = test_data.drop('median_house_value', axis=1), test_data['median_house_value']

# %%
X_test_s = scaler.transform(X_test)

# %%
model.score(X_test_s, y_test)
# Out:
# 0.6787391643087948

# %%
# Random Forest
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(X_train_s, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test_s, y_test)
# Out:
# 0.8192175688575822

# %%
# Grid Seach Cross Validation
from sklearn.model_selection import GridSearchCV

forest = RandomForestRegressor()

param_grid = {
    "n_estimators": [100, 150, 200],
    "min_samples_split": [2, 4]
}

grid_search = GridSearchCV(forest, param_grid, cv=5,
                           scoring = "neg_mean_squared_error",
                           return_train_score = True)

grid_search.fit(X_train_s, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'min_samples_split': [2, 4],
#                          'n_estimators': [100, 150, 200]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(n_estimators=150)

# %%
grid_search.best_estimator_.score(X_test_s, y_test)
# Out:
# 0.820674213582626

# %% [markdown]
# ##### Matplotlib Practice

# %%
# Scatter Plot

plt.figure(figsize=(6, 4))
plt.scatter(data['median_income'], data['median_house_value'], alpha=0.7)
plt.xlabel('Median Income')
plt.ylabel('Median House Value')
plt.title('Median Income vs Median House Value')
plt.show()

# %%
# Line plot
# Simulate
epochs = range(1,8)
train_loss = [7,6,5,4,3,2,1]
val_loss = [8,7,6,5,4,5,6]

plt.figure(figsize=(6, 4))
plt.plot(epochs, train_loss, label='Train')
plt.plot(epochs, val_loss, label='Validation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# Histogram
plt.hist(data['median_house_value'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('Median House Value')
plt.ylabel('Count')
plt.title('Median House Value Distribution')
plt.show()

# %%
# Subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
axes[0].hist(data['median_house_value'])
axes[0].set_title('Median House Value')
axes[1].hist(data['median_income'])
axes[1].set_title('Median Income')
plt.tight_layout() 
plt.savefig('my_plot.png', dpi=300)
plt.show()

# %% [markdown]
# ##### Seaborn Practice

# %%
sns.set(style="whitegrid")

# %%
# Pairplot
sns.pairplot(data[['median_house_value', 'median_income', 'longitude', 'latitude']], hue='median_house_value')
plt.show()

# %%
# Histogram
sns.histplot(data['median_house_value'], bins=30, kde=True, color='steelblue')
plt.title('Median House Value Distribution with KDE')
plt.show()

# %%
# Boxplot
sns.boxplot(x='median_house_value', y='ocean_proximity', data=data)
plt.title('Median House Value by Ocean Proximity')
plt.show()

# %%
# Violin plot
sns.violinplot(x='median_house_value', y='ocean_proximity', data=data)
plt.title('Median House Value by Ocean Proximity')
plt.show()

# %%
# Countplot
sns.countplot(x='ocean_proximity', data=data)
plt.title('Ocean Proximity Class Distribution')
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(10,8))
corr_matrix = data.drop('ocean_proximity', axis=1).corr()
sns.heatmap(corr_matrix, annot=True, cmap = "coolwarm", fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
# Stripplot
sns.stripplot(x='median_house_value', y='ocean_proximity', data=data, jitter=True)
plt.title('Swarmplot of Median House Value by Class')
plt.show()

# %% [markdown]
# ##### Practical examples

# %%
from sklearn.metrics import confusion_matrix

y_true = [0, 1, 0, 1, 0, 1, 1]
y_pred = [0, 1, 0, 0, 0, 1, 1]

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
